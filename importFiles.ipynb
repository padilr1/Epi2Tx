# %%
import pandas as pd

# %%
class exprCounts:
    """
    Class for reading and processing expression counts.
    """
    def __init__(self,counts:str):
        """
        Initialize with the path to a count file.

        Parameters
        ----------
        counts : str
            Path to the CSV file containing expression counts.
        """
        self.counts = counts

    def processCounts(self):
        df = pd.read_csv(self.counts,index_col=False)

        return df

# %%
counts = exprCounts("/Users/padilr1/Documents/Epi2Tx/normCounts/mMSC_TPMcounts.csv")
df = counts.processCounts()
df
# Out:
#                ensembl_id  mMSC_WT_1  mMSC_WT_2  mMSC_WT_3  mMSC_NSD1KO_1  \
# 0      ENSMUSG00000000001  33.749205  30.637487  31.892524      47.141238
# 1      ENSMUSG00000000003   0.000000   0.000000   0.000000       0.000000
# 2      ENSMUSG00000000028   3.052168   5.487439   6.187440      11.470509
# 3      ENSMUSG00000000031   5.926926   0.256783   0.282283       0.395947
# 4      ENSMUSG00000000037   0.761518   1.157364   1.803187       4.381240
# ...                   ...        ...        ...        ...            ...
# 54527  ENSMUSG00000117336   0.000000   0.000000   0.000000       0.000000
# 54528  ENSMUSG00000117337   0.303143   0.000000   0.000000       0.398828
# 54529  ENSMUSG00000117338   0.385840   0.000000   0.000000       0.000000
# 54530  ENSMUSG00000117340   0.000000   0.000000   0.000000       0.000000
# 54531  ENSMUSG00000117341   0.000000   0.000000   0.000000       0.000000
#
#        mMSC_NSD1KO_2  mMSC_NSD1KO_3
# 0          35.479582      42.847752
# 1           0.000000       0.000000
# 2          13.629490      17.743327
# 3           0.072274       0.399482
# 4           5.191825       2.970938
# ...              ...            ...
# 54527       0.000000       0.000000
# 54528       0.000000       0.408513
# 54529       0.000000       0.000000
# 54530       0.000000       0.000000
# 54531       0.000000       0.000000
#
# [54532 rows x 7 columns]
